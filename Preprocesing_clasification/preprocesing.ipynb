# %%
import pandas as pd

# %%
""" Extact data """
df=pd.read_excel('../Data/DATA.xlsx')

# %%
df.head(10)
# Out:
#   APELLIDO PATERNO     APELLIDO MATERNO            NOMBRES  \
# 0             ABAD  TORRES DE BOCANEGRA  FELICITA VICTORIA
# 1           ABANTO              SANCHEZ  PAOLA DEL ROSARIO
# 2          ACEVEDO              CABELLO      ELIZABETH LUZ
# 3          ACEVEDO              CONGORA               LUCY
# 4            ACUÑA              BRICEÑO            SILVIA
# 5           AGUEDA                 VILA           VERONIKA
# 6           AGUERO     MEJIA DE JIMENEZ      KENYI ARIADNA
# 7           AGUILA               GARCIA             URSULA
# 8          AGUILAR                  ORE              MARIA
# 9          AGUIRRE           BARRIENTOS             HELLEN
#
#    A QUE EDAD INICIO SU PRIMERA MESTRUACIÓN?  \
# 0                                         14
# 1                                         10
# 2                                         10
# 3                                         16
# 4                                         12
# ...

# %%
""" Visualize columns"""
df.columns
# Out:
# Index(['APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRES',
#        'A QUE EDAD INICIO SU PRIMERA MESTRUACIÓN?',
#        'A QUE EDAD INICIO SU PRIMERA MESTRUACIÓN?.1',
#        'SU MENUPAUSIA INICIO DESPUES DE SUS 51 AÑOS?',
#        'USTED A ESTADO EXPUESTO A RADIACIÓN?',
#        'USTED TOMA MEDICAMENTOS PARA EL ASMA O ALERGIAS?',
#        'USTED REALIZA ACTIVIDAD FISICA?', 'SUFRE DE OBESIDAD O SOBREPESO?',
#        'NOMBRES.1', 'COMENTARIO', 'COMENTARIO.1'],
#       dtype='object')

# %%
"Drop duplicate columns"
df= df.drop(['NOMBRES.1'], axis=1)
df.head(5)
# Out:
#   APELLIDO PATERNO     APELLIDO MATERNO            NOMBRES  \
# 0             ABAD  TORRES DE BOCANEGRA  FELICITA VICTORIA
# 1           ABANTO              SANCHEZ  PAOLA DEL ROSARIO
# 2          ACEVEDO              CABELLO      ELIZABETH LUZ
# 3          ACEVEDO              CONGORA               LUCY
# 4            ACUÑA              BRICEÑO            SILVIA
#
#    A QUE EDAD INICIO SU PRIMERA MESTRUACIÓN?  \
# 0                                         14
# 1                                         10
# 2                                         10
# 3                                         16
# 4                                         12
#
#    A QUE EDAD INICIO SU PRIMERA MESTRUACIÓN?.1  \
# 0                                           25
# 1                                           33
# 2                                           27
# 3                                           32
# 4                                           24
#
# ...

# %%
"""Rename Columns"""
df.columns = ['ap_paterno', 'ap_materno', 'nombres', 'edad_inic_mestruacion', 'edad_inic_act_sexual', 'menopausia_despues_51anios','exposicion_radiacion', 'asma/alergia_medicacion', 'actividad_fisica', 'sobrepeso/obesidad','comentario','comentario_adic']
df.columns
# Out:
# Index(['ap_paterno', 'ap_materno', 'nombres', 'edad_inic_mestruacion',
#        'edad_inic_act_sexual', 'menopausia_despues_51anios',
#        'exposicion_radiacion', 'asma/alergia_medicacion', 'actividad_fisica',
#        'sobrepeso/obesidad', 'comentario', 'comentario_adic'],
#       dtype='object')

# %%
df.head(5)
# Out:
#   ap_paterno           ap_materno            nombres  edad_inic_mestruacion  \
# 0       ABAD  TORRES DE BOCANEGRA  FELICITA VICTORIA                     14
# 1     ABANTO              SANCHEZ  PAOLA DEL ROSARIO                     10
# 2    ACEVEDO              CABELLO      ELIZABETH LUZ                     10
# 3    ACEVEDO              CONGORA               LUCY                     16
# 4      ACUÑA              BRICEÑO            SILVIA                      12
#
#    edad_inic_act_sexual menopausia_despues_51anios exposicion_radiacion  \
# 0                    25                         NO                   NO
# 1                    33                         SI                   NO
# 2                    27                         SI                   NO
# 3                    32                         SI                   NO
# 4                    24                         SI                   NO
#
#   asma/alergia_medicacion actividad_fisica sobrepeso/obesidad  \
# ...

# %%
df ['comentario'] = df['comentario'].str.replace('AÑO', 'anio')
df ['comentario'] = df['comentario'].str.replace('AÑOS', 'anios')
df ['comentario_adic'] = df['comentario_adic'].str.replace('AÑO', 'anio')
df ['comentario_adic'] = df['comentario_adic'].str.replace('AÑOS', 'anios')
df ['comentario'] = df['comentario'].str.replace('CENO', 'seno')
df ['comentario_adic'] = df['comentario_adic'].str.replace('CENO', 'seno')
df.head()
# Out:
#   ap_paterno           ap_materno            nombres  edad_inic_mestruacion  \
# 0       ABAD  TORRES DE BOCANEGRA  FELICITA VICTORIA                     14
# 1     ABANTO              SANCHEZ  PAOLA DEL ROSARIO                     10
# 2    ACEVEDO              CABELLO      ELIZABETH LUZ                     10
# 3    ACEVEDO              CONGORA               LUCY                     16
# 4      ACUÑA              BRICEÑO            SILVIA                      12
#
#    edad_inic_act_sexual menopausia_despues_51anios exposicion_radiacion  \
# 0                    25                         NO                   NO
# 1                    33                         SI                   NO
# 2                    27                         SI                   NO
# 3                    32                         SI                   NO
# 4                    24                         SI                   NO
#
#   asma/alergia_medicacion actividad_fisica sobrepeso/obesidad  \
# ...

# %%
"""
Lowercase all the coments
The first step is transforming the coments into lowercase to maintain a consistent flow during the NLP tasks
and text mining. For example, 'Virus' and 'virus' will be treated as two different words in any sentence, and
hence, we need to make all the words lowercase in the coments to prevent this duplication.

"""

df['comentario']= df['comentario'].str.lower()
df['comentario_adic']= df['comentario_adic'].str.lower()

"""
Remove Punctuations

For most NLP problems, punctuation does not provide additional language information. So we generally
drop it. Similarly, punctuation symbols are not crucial for sentiment analysis. They are redundant, and the
removal of punctuation before text modeling is highly recommended.

"""
df['comentario']= df['comentario'].str.replace('[^a-zA-Z0-9]+', " ")
df['comentario_adic']= df['comentario_adic'].str.replace('[^a-zA-Z0-9]+', " ")
df.head()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20068\2027443602.py:20: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['comentario']= df['comentario'].str.replace('[^a-zA-Z0-9]+', " ")
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20068\2027443602.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['comentario_adic']= df['comentario_adic'].str.replace('[^a-zA-Z0-9]+', " ")
#   ap_paterno           ap_materno            nombres  edad_inic_mestruacion  \
# 0       ABAD  TORRES DE BOCANEGRA  FELICITA VICTORIA                     14
# 1     ABANTO              SANCHEZ  PAOLA DEL ROSARIO                     10
# 2    ACEVEDO              CABELLO      ELIZABETH LUZ                     10
# 3    ACEVEDO              CONGORA               LUCY                     16
# 4      ACUÑA              BRICEÑO            SILVIA                      12
#
# ...

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('vader_lexicon')
nltk.download('punkt')
## NLTK 1ibrary provides the set of stop words for spanish
nltk.download ('stopwords')
stopwords = stopwords . words ('spanish')
df ['comentario'] = df['comentario']. apply(lambda words : ' '.join (word. lower () for word in words . split() if word not in stopwords))
print(df . head ())
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
#   ap_paterno           ap_materno            nombres  edad_inic_mestruacion  \
# 0       ABAD  TORRES DE BOCANEGRA  FELICITA VICTORIA                     14
# 1     ABANTO              SANCHEZ  PAOLA DEL ROSARIO                     10
# 2    ACEVEDO              CABELLO      ELIZABETH LUZ                     10
# 3    ACEVEDO              CONGORA               LUCY                     16
# 4      ACUÑA              BRICEÑO            SILVIA                      12
#
#    edad_inic_act_sexual menopausia_despues_51anios exposicion_radiacion  \
# 0                    25                         NO                   NO
# 1                    33                         SI                   NO
# 2                    27                         SI                   NO
# 3                    32                         SI                   NO
# ...

# %%
df.head()
# Out:
#   ap_paterno           ap_materno            nombres  edad_inic_mestruacion  \
# 0       ABAD  TORRES DE BOCANEGRA  FELICITA VICTORIA                     14
# 1     ABANTO              SANCHEZ  PAOLA DEL ROSARIO                     10
# 2    ACEVEDO              CABELLO      ELIZABETH LUZ                     10
# 3    ACEVEDO              CONGORA               LUCY                     16
# 4      ACUÑA              BRICEÑO            SILVIA                      12
#
#    edad_inic_act_sexual menopausia_despues_51anios exposicion_radiacion  \
# 0                    25                         NO                   NO
# 1                    33                         SI                   NO
# 2                    27                         SI                   NO
# 3                    32                         SI                   NO
# 4                    24                         SI                   NO
#
#   asma/alergia_medicacion actividad_fisica sobrepeso/obesidad  \
# ...

# %%
df.head()
# Out:
#   ap_paterno           ap_materno            nombres  edad_inic_mestruacion  \
# 0       ABAD  TORRES DE BOCANEGRA  FELICITA VICTORIA                     14
# 1     ABANTO              SANCHEZ  PAOLA DEL ROSARIO                     10
# 2    ACEVEDO              CABELLO      ELIZABETH LUZ                     10
# 3    ACEVEDO              CONGORA               LUCY                     16
# 4      ACUÑA              BRICEÑO            SILVIA                      12
#
#    edad_inic_act_sexual menopausia_despues_51anios exposicion_radiacion  \
# 0                    25                         NO                   NO
# 1                    33                         SI                   NO
# 2                    27                         SI                   NO
# 3                    32                         SI                   NO
# 4                    24                         SI                   NO
#
#   asma/alergia_medicacion actividad_fisica sobrepeso/obesidad  \
# ...

# %%
import nltk
nltk.download('vader_lexicon') # Obligatorio para usar SentimentIntensityAnalyzer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

import hunspell # Nos ayudará con los diccionarios en español
# Buscar diccionarios en carpeta de instalacion
# Más diccionarios de idiomas disponibles en: https://github.com/wooorm/dictionaries/tree/master/dictionaries
diccionario = hunspell.HunSpell('/content/es_MX.dic','/content/es_MX.aff')


from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

# %%
df.head()
# Out:
#   ap_paterno           ap_materno            nombres  edad_inic_mestruacion  \
# 0       ABAD  TORRES DE BOCANEGRA  FELICITA VICTORIA                     14
# 1     ABANTO              SANCHEZ  PAOLA DEL ROSARIO                     10
# 2    ACEVEDO              CABELLO      ELIZABETH LUZ                     10
# 3    ACEVEDO              CONGORA               LUCY                     16
# 4      ACUÑA              BRICEÑO            SILVIA                      12
#
#    edad_inic_act_sexual menopausia_despues_51anios exposicion_radiacion  \
# 0                    25                         NO                   NO
# 1                    33                         SI                   NO
# 2                    27                         SI                   NO
# 3                    32                         SI                   NO
# 4                    24                         SI                   NO
#
#   asma/alergia_medicacion actividad_fisica sobrepeso/obesidad  \
# ...
